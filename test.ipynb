# %%
import matplotlib.pyplot as plt
plt.style.use('/Users/georgia/Active/c4aPys/c4-leafy.mplstyle')

fig = plt.figure()

# Add subplot to figure
ax = fig.add_subplot(111)
# Show empty plot
plt.show()
# Out:
# Bad value in file '/Users/georgia/Active/c4aPys/c4-leafy.mplstyle', line 15 ('axes.prop_cycle: cycler(color=["#F75151","#414042","#B3B299","#05A07E","#004342"])'): Key axes.prop_cycle: 'cycler(color=["' is not a valid cycler construction: EOL while scanning string literal (<string>, line 1)
